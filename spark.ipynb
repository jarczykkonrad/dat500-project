# %%
import findspark
findspark.init()

# %%
import os
os.environ["HADOOP_CONF_DIR"]
# Out:
# '/usr/local/hadoop/etc/hadoop'

# %%
import pyspark
pyspark.__file__
# Out:
# '/home/ubuntu/spark/python/pyspark/__init__.py'

# %%
from pyspark.sql import functions as F
import sparknlp
from sparknlp.base import *
from sparknlp.annotator import *
from pyspark.ml import Pipeline

# %% [markdown]
# import shutil
# shutil.rmtree("/tmp/books")
# shutil.rmtree("/tmp/ratings")

# %%
from pyspark import *
from delta import *

builder = pyspark.sql.SparkSession.builder.appName("MyApp").master("yarn").config("spark.kryoserializer.buffer.max", "2000M") \
    .config("spark.sql.extensions", "io.delta.sql.DeltaSparkSessionExtension") \
    .config("spark.sql.catalog.spark_catalog", "org.apache.spark.sql.delta.catalog.DeltaCatalog") \
    .config("spark.executor.cores", 4) \


spark = configure_spark_with_delta_pip(builder, extra_packages=["com.johnsnowlabs.nlp:spark-nlp_2.12:4.4.0"]).getOrCreate()


sc = spark.sparkContext

logger = sc._jvm.org.apache.log4j
logger.LogManager.getLogger("org").setLevel(logger.Level.OFF)
logger.LogManager.getLogger("akka").setLevel(logger.Level.OFF)

sc.setLogLevel("OFF")
sc
# Out:
# :: loading settings :: url = jar:file:/home/ubuntu/spark/jars/ivy-2.5.1.jar!/org/apache/ivy/core/settings/ivysettings.xml
# Ivy Default Cache set to: /home/ubuntu/.ivy2/cache
# The jars for the packages stored in: /home/ubuntu/.ivy2/jars
# io.delta#delta-core_2.12 added as a dependency
# com.johnsnowlabs.nlp#spark-nlp_2.12 added as a dependency
# :: resolving dependencies :: org.apache.spark#spark-submit-parent-04ac87fd-0373-47e0-97e3-fa90df5d72df;1.0
# 	confs: [default]
# 	found io.delta#delta-core_2.12;2.3.0 in central
# 	found io.delta#delta-storage;2.3.0 in central
# 	found org.antlr#antlr4-runtime;4.8 in central
# 	found com.johnsnowlabs.nlp#spark-nlp_2.12;4.4.0 in central
# 	found com.typesafe#config;1.4.2 in central
# 	found org.rocksdb#rocksdbjni;6.29.5 in central
# 	found com.amazonaws#aws-java-sdk-bundle;1.11.828 in central
# 	found com.github.universal-automata#liblevenshtein;3.0.0 in central
# 	found com.google.protobuf#protobuf-java-util;3.0.0-beta-3 in central
# 	found com.google.protobuf#protobuf-java;3.0.0-beta-3 in central
# 	found com.google.code.gson#gson;2.3 in central
# 	found it.unimi.dsi#fastutil;7.0.12 in central
# 	found org.projectlombok#lombok;1.16.8 in central
# 	found com.google.cloud#google-cloud-storage;2.16.0 in central
# 	found com.google.guava#guava;31.1-jre in central
# 	found com.google.guava#failureaccess;1.0.1 in spark-list
# 	found com.google.guava#listenablefuture;9999.0-empty-to-avoid-conflict-with-guava in central
# 	found com.google.errorprone#error_prone_annotations;2.16 in central
# 	found com.google.j2objc#j2objc-annotations;1.3 in central
# 	found com.google.http-client#google-http-client;1.42.3 in central
# 	found io.opencensus#opencensus-contrib-http-util;0.31.1 in central
# 	found com.google.http-client#google-http-client-jackson2;1.42.3 in central
# 	found com.google.http-client#google-http-client-gson;1.42.3 in central
# 	found com.google.api-client#google-api-client;2.1.1 in central
# 	found commons-codec#commons-codec;1.15 in central
# 	found com.google.oauth-client#google-oauth-client;1.34.1 in central
# 	found com.google.http-client#google-http-client-apache-v2;1.42.3 in central
# 	found com.google.apis#google-api-services-storage;v1-rev20220705-2.0.0 in spark-list
# 	found com.google.code.gson#gson;2.10 in central
# 	found com.google.cloud#google-cloud-core;2.9.0 in spark-list
# 	found com.google.auto.value#auto-value-annotations;1.10.1 in central
# 	found com.google.cloud#google-cloud-core-http;2.9.0 in central
# 	found com.google.http-client#google-http-client-appengine;1.42.3 in central
# 	found com.google.api#gax-httpjson;0.105.1 in central
# 	found com.google.cloud#google-cloud-core-grpc;2.9.0 in central
# 	found io.grpc#grpc-core;1.51.0 in central
# 	found com.google.api#gax;2.20.1 in central
# 	found com.google.api#gax-grpc;2.20.1 in central
# 	found io.grpc#grpc-alts;1.51.0 in central
# 	found io.grpc#grpc-grpclb;1.51.0 in central
# 	found org.conscrypt#conscrypt-openjdk-uber;2.5.2 in central
# 	found io.grpc#grpc-protobuf;1.51.0 in central
# 	found com.google.auth#google-auth-library-credentials;1.13.0 in central
# 	found com.google.auth#google-auth-library-oauth2-http;1.13.0 in central
# 	found com.google.api#api-common;2.2.2 in central
# 	found javax.annotation#javax.annotation-api;1.3.2 in central
# 	found io.opencensus#opencensus-api;0.31.1 in central
# 	found io.grpc#grpc-context;1.51.0 in central
# 	found com.google.api.grpc#proto-google-iam-v1;1.6.22 in spark-list
# 	found com.google.protobuf#protobuf-java;3.21.10 in central
# 	found com.google.protobuf#protobuf-java-util;3.21.10 in central
# 	found com.google.api.grpc#proto-google-common-protos;2.11.0 in central
# 	found org.threeten#threetenbp;1.6.4 in central
# 	found com.google.api.grpc#proto-google-cloud-storage-v2;2.16.0-alpha in central
# 	found com.google.api.grpc#grpc-google-cloud-storage-v2;2.16.0-alpha in central
# 	found com.google.api.grpc#gapic-google-cloud-storage-v2;2.16.0-alpha in central
# 	found com.fasterxml.jackson.core#jackson-core;2.14.1 in central
# 	found com.google.code.findbugs#jsr305;3.0.2 in central
# 	found io.grpc#grpc-api;1.51.0 in central
# 	found io.grpc#grpc-auth;1.51.0 in central
# 	found io.grpc#grpc-stub;1.51.0 in central
# 	found org.checkerframework#checker-qual;3.28.0 in central
# 	found com.google.api.grpc#grpc-google-iam-v1;1.6.22 in central
# 	found io.grpc#grpc-protobuf-lite;1.51.0 in central
# 	found com.google.android#annotations;4.1.1.4 in central
# 	found org.codehaus.mojo#animal-sniffer-annotations;1.22 in central
# 	found io.grpc#grpc-netty-shaded;1.51.0 in central
# 	found io.perfmark#perfmark-api;0.26.0 in central
# 	found io.grpc#grpc-googleapis;1.51.0 in central
# 	found io.grpc#grpc-xds;1.51.0 in central
# 	found io.opencensus#opencensus-proto;0.2.0 in central
# 	found io.grpc#grpc-services;1.51.0 in central
# 	found com.google.re2j#re2j;1.6 in central
# 	found com.navigamez#greex;1.0 in central
# 	found dk.brics.automaton#automaton;1.11-8 in spark-list
# 	found com.johnsnowlabs.nlp#tensorflow-cpu_2.12;0.4.4 in central
# :: resolution report :: resolve 2904ms :: artifacts dl 115ms
# 	:: modules in use:
# 	com.amazonaws#aws-java-sdk-bundle;1.11.828 from central in [default]
# 	com.fasterxml.jackson.core#jackson-core;2.14.1 from central in [default]
# 	com.github.universal-automata#liblevenshtein;3.0.0 from central in [default]
# 	com.google.android#annotations;4.1.1.4 from central in [default]
# 	com.google.api#api-common;2.2.2 from central in [default]
# 	com.google.api#gax;2.20.1 from central in [default]
# 	com.google.api#gax-grpc;2.20.1 from central in [default]
# 	com.google.api#gax-httpjson;0.105.1 from central in [default]
# 	com.google.api-client#google-api-client;2.1.1 from central in [default]
# 	com.google.api.grpc#gapic-google-cloud-storage-v2;2.16.0-alpha from central in [default]
# 	com.google.api.grpc#grpc-google-cloud-storage-v2;2.16.0-alpha from central in [default]
# 	com.google.api.grpc#grpc-google-iam-v1;1.6.22 from central in [default]
# 	com.google.api.grpc#proto-google-cloud-storage-v2;2.16.0-alpha from central in [default]
# 	com.google.api.grpc#proto-google-common-protos;2.11.0 from central in [default]
# 	com.google.api.grpc#proto-google-iam-v1;1.6.22 from spark-list in [default]
# 	com.google.apis#google-api-services-storage;v1-rev20220705-2.0.0 from spark-list in [default]
# 	com.google.auth#google-auth-library-credentials;1.13.0 from central in [default]
# 	com.google.auth#google-auth-library-oauth2-http;1.13.0 from central in [default]
# 	com.google.auto.value#auto-value-annotations;1.10.1 from central in [default]
# 	com.google.cloud#google-cloud-core;2.9.0 from spark-list in [default]
# 	com.google.cloud#google-cloud-core-grpc;2.9.0 from central in [default]
# 	com.google.cloud#google-cloud-core-http;2.9.0 from central in [default]
# 	com.google.cloud#google-cloud-storage;2.16.0 from central in [default]
# 	com.google.code.findbugs#jsr305;3.0.2 from central in [default]
# 	com.google.code.gson#gson;2.10 from central in [default]
# 	com.google.errorprone#error_prone_annotations;2.16 from central in [default]
# 	com.google.guava#failureaccess;1.0.1 from spark-list in [default]
# 	com.google.guava#guava;31.1-jre from central in [default]
# 	com.google.guava#listenablefuture;9999.0-empty-to-avoid-conflict-with-guava from central in [default]
# 	com.google.http-client#google-http-client;1.42.3 from central in [default]
# 	com.google.http-client#google-http-client-apache-v2;1.42.3 from central in [default]
# 	com.google.http-client#google-http-client-appengine;1.42.3 from central in [default]
# 	com.google.http-client#google-http-client-gson;1.42.3 from central in [default]
# 	com.google.http-client#google-http-client-jackson2;1.42.3 from central in [default]
# 	com.google.j2objc#j2objc-annotations;1.3 from central in [default]
# 	com.google.oauth-client#google-oauth-client;1.34.1 from central in [default]
# 	com.google.protobuf#protobuf-java;3.21.10 from central in [default]
# 	com.google.protobuf#protobuf-java-util;3.21.10 from central in [default]
# 	com.google.re2j#re2j;1.6 from central in [default]
# 	com.johnsnowlabs.nlp#spark-nlp_2.12;4.4.0 from central in [default]
# 	com.johnsnowlabs.nlp#tensorflow-cpu_2.12;0.4.4 from central in [default]
# 	com.navigamez#greex;1.0 from central in [default]
# 	com.typesafe#config;1.4.2 from central in [default]
# 	commons-codec#commons-codec;1.15 from central in [default]
# 	dk.brics.automaton#automaton;1.11-8 from spark-list in [default]
# 	io.delta#delta-core_2.12;2.3.0 from central in [default]
# 	io.delta#delta-storage;2.3.0 from central in [default]
# 	io.grpc#grpc-alts;1.51.0 from central in [default]
# 	io.grpc#grpc-api;1.51.0 from central in [default]
# 	io.grpc#grpc-auth;1.51.0 from central in [default]
# 	io.grpc#grpc-context;1.51.0 from central in [default]
# 	io.grpc#grpc-core;1.51.0 from central in [default]
# 	io.grpc#grpc-googleapis;1.51.0 from central in [default]
# 	io.grpc#grpc-grpclb;1.51.0 from central in [default]
# 	io.grpc#grpc-netty-shaded;1.51.0 from central in [default]
# 	io.grpc#grpc-protobuf;1.51.0 from central in [default]
# 	io.grpc#grpc-protobuf-lite;1.51.0 from central in [default]
# 	io.grpc#grpc-services;1.51.0 from central in [default]
# 	io.grpc#grpc-stub;1.51.0 from central in [default]
# 	io.grpc#grpc-xds;1.51.0 from central in [default]
# 	io.opencensus#opencensus-api;0.31.1 from central in [default]
# 	io.opencensus#opencensus-contrib-http-util;0.31.1 from central in [default]
# 	io.opencensus#opencensus-proto;0.2.0 from central in [default]
# 	io.perfmark#perfmark-api;0.26.0 from central in [default]
# 	it.unimi.dsi#fastutil;7.0.12 from central in [default]
# 	javax.annotation#javax.annotation-api;1.3.2 from central in [default]
# 	org.antlr#antlr4-runtime;4.8 from central in [default]
# 	org.checkerframework#checker-qual;3.28.0 from central in [default]
# 	org.codehaus.mojo#animal-sniffer-annotations;1.22 from central in [default]
# 	org.conscrypt#conscrypt-openjdk-uber;2.5.2 from central in [default]
# 	org.projectlombok#lombok;1.16.8 from central in [default]
# 	org.rocksdb#rocksdbjni;6.29.5 from central in [default]
# 	org.threeten#threetenbp;1.6.4 from central in [default]
# 	:: evicted modules:
# 	com.google.protobuf#protobuf-java-util;3.0.0-beta-3 by [com.google.protobuf#protobuf-java-util;3.21.10] in [default]
# 	com.google.protobuf#protobuf-java;3.0.0-beta-3 by [com.google.protobuf#protobuf-java;3.21.10] in [default]
# 	com.google.code.gson#gson;2.3 by [com.google.code.gson#gson;2.10] in [default]
# 	---------------------------------------------------------------------
# 	|                  |            modules            ||   artifacts   |
# 	|       conf       | number| search|dwnlded|evicted|| number|dwnlded|
# 	---------------------------------------------------------------------
# 	|      default     |   76  |   0   |   0   |   3   ||   73  |   0   |
# 	---------------------------------------------------------------------
# :: retrieving :: org.apache.spark#spark-submit-parent-04ac87fd-0373-47e0-97e3-fa90df5d72df
# 	confs: [default]
# 	0 artifacts copied, 73 already retrieved (0kB/35ms)
# 2023-05-05 15:28:30,003 INFO spark.SparkContext: Running Spark version 3.3.2
# 2023-05-05 15:28:30,070 INFO resource.ResourceUtils: ==============================================================
# 2023-05-05 15:28:30,070 INFO resource.ResourceUtils: No custom resources configured for spark.driver.
# 2023-05-05 15:28:30,071 INFO resource.ResourceUtils: ==============================================================
# 2023-05-05 15:28:30,072 INFO spark.SparkContext: Submitted application: MyApp
# 2023-05-05 15:28:30,127 INFO resource.ResourceProfile: Default ResourceProfile created, executor resources: Map(cores -> name: cores, amount: 4, script: , vendor: , memory -> name: memory, amount: 1024, script: , vendor: , offHeap -> name: offHeap, amount: 0, script: , vendor: ), task resources: Map(cpus -> name: cpus, amount: 1.0)
# 2023-05-05 15:28:30,152 INFO resource.ResourceProfile: Limiting resource is cpus at 4 tasks per executor
# 2023-05-05 15:28:30,155 INFO resource.ResourceProfileManager: Added ResourceProfile id: 0
# 2023-05-05 15:28:30,357 INFO spark.SecurityManager: Changing view acls to: ubuntu
# 2023-05-05 15:28:30,358 INFO spark.SecurityManager: Changing modify acls to: ubuntu
# 2023-05-05 15:28:30,358 INFO spark.SecurityManager: Changing view acls groups to:
# 2023-05-05 15:28:30,359 INFO spark.SecurityManager: Changing modify acls groups to:
# 2023-05-05 15:28:30,360 INFO spark.SecurityManager: SecurityManager: authentication disabled; ui acls disabled; users  with view permissions: Set(ubuntu); groups with view permissions: Set(); users  with modify permissions: Set(ubuntu); groups with modify permissions: Set()
# 2023-05-05 15:28:31,232 INFO util.Utils: Successfully started service 'sparkDriver' on port 39767.
# 2023-05-05 15:28:31,307 INFO spark.SparkEnv: Registering MapOutputTracker
# 2023-05-05 15:28:31,472 INFO spark.SparkEnv: Registering BlockManagerMaster
# 2023-05-05 15:28:31,519 INFO storage.BlockManagerMasterEndpoint: Using org.apache.spark.storage.DefaultTopologyMapper for getting topology information
# 2023-05-05 15:28:31,519 INFO storage.BlockManagerMasterEndpoint: BlockManagerMasterEndpoint up
# 2023-05-05 15:28:31,632 INFO spark.SparkEnv: Registering BlockManagerMasterHeartbeat
# 2023-05-05 15:28:31,701 INFO storage.DiskBlockManager: Created local directory at /tmp/blockmgr-c488b91b-93b0-4c25-9c9c-ef14bc0b2438
# 2023-05-05 15:28:31,752 INFO memory.MemoryStore: MemoryStore started with capacity 366.3 MiB
# 2023-05-05 15:28:31,833 INFO spark.SparkEnv: Registering OutputCommitCoordinator
# 2023-05-05 15:28:31,997 INFO util.log: Logging initialized @15447ms to org.sparkproject.jetty.util.log.Slf4jLog
# 2023-05-05 15:28:32,292 INFO server.Server: jetty-9.4.48.v20220622; built: 2022-06-21T20:42:25.880Z; git: 6b67c5719d1f4371b33655ff2d047d24e171e49a; jvm 1.8.0_362-8u362-ga-0ubuntu1~20.04.1-b09
# 2023-05-05 15:28:32,391 INFO server.Server: Started @15843ms
# 2023-05-05 15:28:32,457 INFO server.AbstractConnector: Started ServerConnector@596d4995{HTTP/1.1, (http/1.1)}{0.0.0.0:4040}
# 2023-05-05 15:28:32,457 INFO util.Utils: Successfully started service 'SparkUI' on port 4040.
# 2023-05-05 15:28:32,496 INFO handler.ContextHandler: Started o.s.j.s.ServletContextHandler@74e5f78d{/,null,AVAILABLE,@Spark}
# 2023-05-05 15:28:33,867 INFO client.RMProxy: Connecting to ResourceManager at namenode/192.168.18.51:8032
# 2023-05-05 15:28:35,887 INFO conf.Configuration: resource-types.xml not found
# 2023-05-05 15:28:35,889 INFO resource.ResourceUtils: Unable to find 'resource-types.xml'.
# 2023-05-05 15:28:35,920 INFO yarn.Client: Verifying our application has not requested more than the maximum memory capability of the cluster (8192 MB per container)
# 2023-05-05 15:28:35,920 INFO yarn.Client: Will allocate AM container, with 896 MB memory including 384 MB overhead
# 2023-05-05 15:28:35,921 INFO yarn.Client: Setting up container launch context for our AM
# 2023-05-05 15:28:35,924 INFO yarn.Client: Setting up the launch environment for our AM container
# 2023-05-05 15:28:35,942 INFO yarn.Client: Preparing resources for our AM container
# 2023-05-05 15:28:35,997 WARN yarn.Client: Neither spark.yarn.jars nor spark.yarn.archive is set, falling back to uploading libraries under SPARK_HOME.
# 2023-05-05 15:28:43,102 INFO yarn.Client: Uploading resource file:/tmp/spark-b9e75af4-33b9-45eb-99f1-99e73e11f69f/__spark_libs__7989207462518549756.zip -> hdfs://namenode:9000/user/ubuntu/.sparkStaging/application_1683296918015_0005
INFO sasl.SaslDataTransferClient: SASL encryption trust check: localHostTrusted = false, remoteHostTrusted = false
# 2023-05-05 15:29:04,356 INFO yarn.Client: Uploading resource file:/home/ubuntu/.ivy2/jars/com.google.cloud_google-cloud-core-2.9.0.jar -> hdfs://namenode:9000/user/ubuntu/.sparkStaging/application_1683296918015_0005/com.google.cloud_google-cloud-core-2.9.0.jar
# 2023-05-05 15:29:04,420 INFO sasl.SaslDataTransferClient: SASL encryption trust check: localHostTrusted = false, remoteHostTrusted = false
# 2023-05-05 15:29:05,323 INFO yarn.Client: Uploading resource file:/home/ubuntu/.ivy2/jars/com.google.auto.value_auto-value-annotations-1.10.1.jar -> hdfs://namenode:9000/user/ubuntu/.sparkStaging/application_1683296918015_0005/com.google.auto.value_auto-value-annotations-1.10.1.jar
# 2023-05-05 15:29:05,387 INFO sasl.SaslDataTransferClient: SASL encryption trust check: localHostTrusted = false, remoteHostTrusted = false
# 2023-05-05 15:29:05,477 INFO yarn.Client: Uploading resource file:/home/ubuntu/.ivy2/jars/com.google.cloud_google-cloud-core-http-2.9.0.jar -> hdfs://namenode:9000/user/ubuntu/.sparkStaging/application_1683296918015_0005/com.google.cloud_google-cloud-core-http-2.9.0.jar
# 2023-05-05 15:29:05,613 INFO sasl.SaslDataTransferClient: SASL encryption trust check: localHostTrusted = false, remoteHostTrusted = false
# 2023-05-05 15:29:05,673 INFO yarn.Client: Uploading resource file:/home/ubuntu/.ivy2/jars/com.google.http-client_google-http-client-appengine-1.42.3.jar -> hdfs://namenode:9000/user/ubuntu/.sparkStaging/application_1683296918015_0005/com.google.http-client_google-http-client-appengine-1.42.3.jar
# 2023-05-05 15:29:05,722 INFO sasl.SaslDataTransferClient: SASL encryption trust check: localHostTrusted = false, remoteHostTrusted = false
# 2023-05-05 15:29:05,773 INFO yarn.Client: Uploading resource file:/home/ubuntu/.ivy2/jars/com.google.api_gax-httpjson-0.105.1.jar -> hdfs://namenode:9000/user/ubuntu/.sparkStaging/application_1683296918015_0005/com.google.api_gax-httpjson-0.105.1.jar
# 2023-05-05 15:29:05,837 INFO sasl.SaslDataTransferClient: SASL encryption trust check: localHostTrusted = false, remoteHostTrusted = false
# 2023-05-05 15:29:05,923 INFO yarn.Client: Uploading resource file:/home/ubuntu/.ivy2/jars/com.google.cloud_google-cloud-core-grpc-2.9.0.jar -> hdfs://namenode:9000/user/ubuntu/.sparkStaging/application_1683296918015_0005/com.google.cloud_google-cloud-core-grpc-2.9.0.jar
# 2023-05-05 15:29:06,004 INFO sasl.SaslDataTransferClient: SASL encryption trust check: localHostTrusted = false, remoteHostTrusted = false
# 2023-05-05 15:29:06,064 INFO yarn.Client: Uploading resource file:/home/ubuntu/.ivy2/jars/io.grpc_grpc-core-1.51.0.jar -> hdfs://namenode:9000/user/ubuntu/.sparkStaging/application_1683296918015_0005/io.grpc_grpc-core-1.51.0.jar
# 2023-05-05 15:29:06,128 INFO sasl.SaslDataTransferClient: SASL encryption trust check: localHostTrusted = false, remoteHostTrusted = false
# 2023-05-05 15:29:06,200 INFO yarn.Client: Uploading resource file:/home/ubuntu/.ivy2/jars/com.google.api_gax-2.20.1.jar -> hdfs://namenode:9000/user/ubuntu/.sparkStaging/application_1683296918015_0005/com.google.api_gax-2.20.1.jar
# 2023-05-05 15:29:06,289 INFO sasl.SaslDataTransferClient: SASL encryption trust check: localHostTrusted = false, remoteHostTrusted = false
# 2023-05-05 15:29:06,376 INFO yarn.Client: Uploading resource file:/home/ubuntu/.ivy2/jars/com.google.api_gax-grpc-2.20.1.jar -> hdfs://namenode:9000/user/ubuntu/.sparkStaging/application_1683296918015_0005/com.google.api_gax-grpc-2.20.1.jar
# 2023-05-05 15:29:06,431 INFO sasl.SaslDataTransferClient: SASL encryption trust check: localHostTrusted = false, remoteHostTrusted = false
# 2023-05-05 15:29:06,472 INFO yarn.Client: Uploading resource file:/home/ubuntu/.ivy2/jars/io.grpc_grpc-alts-1.51.0.jar -> hdfs://namenode:9000/user/ubuntu/.sparkStaging/application_1683296918015_0005/io.grpc_grpc-alts-1.51.0.jar
# 2023-05-05 15:29:06,598 INFO sasl.SaslDataTransferClient: SASL encryption trust check: localHostTrusted = false, remoteHostTrusted = false
# 2023-05-05 15:29:06,647 INFO yarn.Client: Uploading resource file:/home/ubuntu/.ivy2/jars/io.grpc_grpc-grpclb-1.51.0.jar -> hdfs://namenode:9000/user/ubuntu/.sparkStaging/application_1683296918015_0005/io.grpc_grpc-grpclb-1.51.0.jar
# 2023-05-05 15:29:06,737 INFO sasl.SaslDataTransferClient: SASL encryption trust check: localHostTrusted = false, remoteHostTrusted = false
# 2023-05-05 15:29:06,797 INFO yarn.Client: Uploading resource file:/home/ubuntu/.ivy2/jars/org.conscrypt_conscrypt-openjdk-uber-2.5.2.jar -> hdfs://namenode:9000/user/ubuntu/.sparkStaging/application_1683296918015_0005/org.conscrypt_conscrypt-openjdk-uber-2.5.2.jar
# 2023-05-05 15:29:06,916 INFO sasl.SaslDataTransferClient: SASL encryption trust check: localHostTrusted = false, remoteHostTrusted = false
# 2023-05-05 15:29:07,164 INFO yarn.Client: Uploading resource file:/home/ubuntu/.ivy2/jars/io.grpc_grpc-protobuf-1.51.0.jar -> hdfs://namenode:9000/user/ubuntu/.sparkStaging/application_1683296918015_0005/io.grpc_grpc-protobuf-1.51.0.jar
# 2023-05-05 15:29:07,237 INFO sasl.SaslDataTransferClient: SASL encryption trust check: localHostTrusted = false, remoteHostTrusted = false
# 2023-05-05 15:29:07,298 INFO yarn.Client: Uploading resource file:/home/ubuntu/.ivy2/jars/com.google.auth_google-auth-library-credentials-1.13.0.jar -> hdfs://namenode:9000/user/ubuntu/.sparkStaging/application_1683296918015_0005/com.google.auth_google-auth-library-credentials-1.13.0.jar
# 2023-05-05 15:29:07,337 INFO sasl.SaslDataTransferClient: SASL encryption trust check: localHostTrusted = false, remoteHostTrusted = false
# 2023-05-05 15:29:07,397 INFO yarn.Client: Uploading resource file:/home/ubuntu/.ivy2/jars/com.google.auth_google-auth-library-oauth2-http-1.13.0.jar -> hdfs://namenode:9000/user/ubuntu/.sparkStaging/application_1683296918015_0005/com.google.auth_google-auth-library-oauth2-http-1.13.0.jar
# 2023-05-05 15:29:07,470 INFO sasl.SaslDataTransferClient: SASL encryption trust check: localHostTrusted = false, remoteHostTrusted = false
# 2023-05-05 15:29:08,231 INFO yarn.Client: Uploading resource file:/home/ubuntu/.ivy2/jars/com.google.api_api-common-2.2.2.jar -> hdfs://namenode:9000/user/ubuntu/.sparkStaging/application_1683296918015_0005/com.google.api_api-common-2.2.2.jar
# 2023-05-05 15:29:08,305 INFO sasl.SaslDataTransferClient: SASL encryption trust check: localHostTrusted = false, remoteHostTrusted = false
# 2023-05-05 15:29:08,372 INFO yarn.Client: Uploading resource file:/home/ubuntu/.ivy2/jars/javax.annotation_javax.annotation-api-1.3.2.jar -> hdfs://namenode:9000/user/ubuntu/.sparkStaging/application_1683296918015_0005/javax.annotation_javax.annotation-api-1.3.2.jar
# 2023-05-05 15:29:08,454 INFO sasl.SaslDataTransferClient: SASL encryption trust check: localHostTrusted = false, remoteHostTrusted = false
# 2023-05-05 15:29:08,514 INFO yarn.Client: Uploading resource file:/home/ubuntu/.ivy2/jars/io.opencensus_opencensus-api-0.31.1.jar -> hdfs://namenode:9000/user/ubuntu/.sparkStaging/application_1683296918015_0005/io.opencensus_opencensus-api-0.31.1.jar
# 2023-05-05 15:29:08,562 INFO sasl.SaslDataTransferClient: SASL encryption trust check: localHostTrusted = false, remoteHostTrusted = false
# 2023-05-05 15:29:08,615 INFO yarn.Client: Uploading resource file:/home/ubuntu/.ivy2/jars/io.grpc_grpc-context-1.51.0.jar -> hdfs://namenode:9000/user/ubuntu/.sparkStaging/application_1683296918015_0005/io.grpc_grpc-context-1.51.0.jar
# 2023-05-05 15:29:08,670 INFO sasl.SaslDataTransferClient: SASL encryption trust check: localHostTrusted = false, remoteHostTrusted = false
# 2023-05-05 15:29:08,741 INFO yarn.Client: Uploading resource file:/home/ubuntu/.ivy2/jars/com.google.api.grpc_proto-google-iam-v1-1.6.22.jar -> hdfs://namenode:9000/user/ubuntu/.sparkStaging/application_1683296918015_0005/com.google.api.grpc_proto-google-iam-v1-1.6.22.jar
# 2023-05-05 15:29:08,812 INFO sasl.SaslDataTransferClient: SASL encryption trust check: localHostTrusted = false, remoteHostTrusted = false
# 2023-05-05 15:29:08,883 INFO yarn.Client: Uploading resource file:/home/ubuntu/.ivy2/jars/com.google.protobuf_protobuf-java-3.21.10.jar -> hdfs://namenode:9000/user/ubuntu/.sparkStaging/application_1683296918015_0005/com.google.protobuf_protobuf-java-3.21.10.jar
# 2023-05-05 15:29:08,931 INFO sasl.SaslDataTransferClient: SASL encryption trust check: localHostTrusted = false, remoteHostTrusted = false
# 2023-05-05 15:29:09,233 INFO yarn.Client: Uploading resource file:/home/ubuntu/.ivy2/jars/com.google.protobuf_protobuf-java-util-3.21.10.jar -> hdfs://namenode:9000/user/ubuntu/.sparkStaging/application_1683296918015_0005/com.google.protobuf_protobuf-java-util-3.21.10.jar
# 2023-05-05 15:29:09,279 INFO sasl.SaslDataTransferClient: SASL encryption trust check: localHostTrusted = false, remoteHostTrusted = false
# 2023-05-05 15:29:09,314 INFO yarn.Client: Uploading resource file:/home/ubuntu/.ivy2/jars/com.google.api.grpc_proto-google-common-protos-2.11.0.jar -> hdfs://namenode:9000/user/ubuntu/.sparkStaging/application_1683296918015_0005/com.google.api.grpc_proto-google-common-protos-2.11.0.jar
# 2023-05-05 15:29:09,467 INFO sasl.SaslDataTransferClient: SASL encryption trust check: localHostTrusted = false, remoteHostTrusted = false
# 2023-05-05 15:29:09,523 INFO yarn.Client: Uploading resource file:/home/ubuntu/.ivy2/jars/org.threeten_threetenbp-1.6.4.jar -> hdfs://namenode:9000/user/ubuntu/.sparkStaging/application_1683296918015_0005/org.threeten_threetenbp-1.6.4.jar
# 2023-05-05 15:29:09,629 INFO sasl.SaslDataTransferClient: SASL encryption trust check: localHostTrusted = false, remoteHostTrusted = false
# 2023-05-05 15:29:09,690 INFO yarn.Client: Uploading resource file:/home/ubuntu/.ivy2/jars/com.google.api.grpc_proto-google-cloud-storage-v2-2.16.0-alpha.jar -> hdfs://namenode:9000/user/ubuntu/.sparkStaging/application_1683296918015_0005/com.google.api.grpc_proto-google-cloud-storage-v2-2.16.0-alpha.jar
# 2023-05-05 15:29:09,862 INFO sasl.SaslDataTransferClient: SASL encryption trust check: localHostTrusted = false, remoteHostTrusted = false
# 2023-05-05 15:29:09,939 INFO yarn.Client: Uploading resource file:/home/ubuntu/.ivy2/jars/com.google.api.grpc_grpc-google-cloud-storage-v2-2.16.0-alpha.jar -> hdfs://namenode:9000/user/ubuntu/.sparkStaging/application_1683296918015_0005/com.google.api.grpc_grpc-google-cloud-storage-v2-2.16.0-alpha.jar
# 2023-05-05 15:29:10,004 INFO sasl.SaslDataTransferClient: SASL encryption trust check: localHostTrusted = false, remoteHostTrusted = false
# 2023-05-05 15:29:10,089 INFO yarn.Client: Uploading resource file:/home/ubuntu/.ivy2/jars/com.google.api.grpc_gapic-google-cloud-storage-v2-2.16.0-alpha.jar -> hdfs://namenode:9000/user/ubuntu/.sparkStaging/application_1683296918015_0005/com.google.api.grpc_gapic-google-cloud-storage-v2-2.16.0-alpha.jar
# 2023-05-05 15:29:10,237 INFO sasl.SaslDataTransferClient: SASL encryption trust check: localHostTrusted = false, remoteHostTrusted = false
# 2023-05-05 15:29:10,280 INFO yarn.Client: Uploading resource file:/home/ubuntu/.ivy2/jars/com.fasterxml.jackson.core_jackson-core-2.14.1.jar -> hdfs://namenode:9000/user/ubuntu/.sparkStaging/application_1683296918015_0005/com.fasterxml.jackson.core_jackson-core-2.14.1.jar
# 2023-05-05 15:29:10,345 INFO sasl.SaslDataTransferClient: SASL encryption trust check: localHostTrusted = false, remoteHostTrusted = false
# 2023-05-05 15:29:10,431 INFO yarn.Client: Uploading resource file:/home/ubuntu/.ivy2/jars/com.google.code.findbugs_jsr305-3.0.2.jar -> hdfs://namenode:9000/user/ubuntu/.sparkStaging/application_1683296918015_0005/com.google.code.findbugs_jsr305-3.0.2.jar
# 2023-05-05 15:29:10,522 INFO sasl.SaslDataTransferClient: SASL encryption trust check: localHostTrusted = false, remoteHostTrusted = false
# 2023-05-05 15:29:10,581 INFO yarn.Client: Uploading resource file:/home/ubuntu/.ivy2/jars/io.grpc_grpc-api-1.51.0.jar -> hdfs://namenode:9000/user/ubuntu/.sparkStaging/application_1683296918015_0005/io.grpc_grpc-api-1.51.0.jar
# 2023-05-05 15:29:10,654 INFO sasl.SaslDataTransferClient: SASL encryption trust check: localHostTrusted = false, remoteHostTrusted = false
# 2023-05-05 15:29:10,739 INFO yarn.Client: Uploading resource file:/home/ubuntu/.ivy2/jars/io.grpc_grpc-auth-1.51.0.jar -> hdfs://namenode:9000/user/ubuntu/.sparkStaging/application_1683296918015_0005/io.grpc_grpc-auth-1.51.0.jar
# 2023-05-05 15:29:10,779 INFO sasl.SaslDataTransferClient: SASL encryption trust check: localHostTrusted = false, remoteHostTrusted = false
# 2023-05-05 15:29:10,833 INFO yarn.Client: Uploading resource file:/home/ubuntu/.ivy2/jars/io.grpc_grpc-stub-1.51.0.jar -> hdfs://namenode:9000/user/ubuntu/.sparkStaging/application_1683296918015_0005/io.grpc_grpc-stub-1.51.0.jar
# 2023-05-05 15:29:10,912 INFO sasl.SaslDataTransferClient: SASL encryption trust check: localHostTrusted = false, remoteHostTrusted = false
# 2023-05-05 15:29:10,964 INFO yarn.Client: Uploading resource file:/home/ubuntu/.ivy2/jars/org.checkerframework_checker-qual-3.28.0.jar -> hdfs://namenode:9000/user/ubuntu/.sparkStaging/application_1683296918015_0005/org.checkerframework_checker-qual-3.28.0.jar
# 2023-05-05 15:29:11,046 INFO sasl.SaslDataTransferClient: SASL encryption trust check: localHostTrusted = false, remoteHostTrusted = false
# 2023-05-05 15:29:11,115 INFO yarn.Client: Uploading resource file:/home/ubuntu/.ivy2/jars/com.google.api.grpc_grpc-google-iam-v1-1.6.22.jar -> hdfs://namenode:9000/user/ubuntu/.sparkStaging/application_1683296918015_0005/com.google.api.grpc_grpc-google-iam-v1-1.6.22.jar
# 2023-05-05 15:29:11,145 INFO sasl.SaslDataTransferClient: SASL encryption trust check: localHostTrusted = false, remoteHostTrusted = false
# 2023-05-05 15:29:11,189 INFO yarn.Client: Uploading resource file:/home/ubuntu/.ivy2/jars/io.grpc_grpc-protobuf-lite-1.51.0.jar -> hdfs://namenode:9000/user/ubuntu/.sparkStaging/application_1683296918015_0005/io.grpc_grpc-protobuf-lite-1.51.0.jar
# 2023-05-05 15:29:11,238 INFO sasl.SaslDataTransferClient: SASL encryption trust check: localHostTrusted = false, remoteHostTrusted = false
# 2023-05-05 15:29:11,331 INFO yarn.Client: Uploading resource file:/home/ubuntu/.ivy2/jars/com.google.android_annotations-4.1.1.4.jar -> hdfs://namenode:9000/user/ubuntu/.sparkStaging/application_1683296918015_0005/com.google.android_annotations-4.1.1.4.jar
# 2023-05-05 15:29:11,412 INFO sasl.SaslDataTransferClient: SASL encryption trust check: localHostTrusted = false, remoteHostTrusted = false
# 2023-05-05 15:29:11,465 INFO yarn.Client: Uploading resource file:/home/ubuntu/.ivy2/jars/org.codehaus.mojo_animal-sniffer-annotations-1.22.jar -> hdfs://namenode:9000/user/ubuntu/.sparkStaging/application_1683296918015_0005/org.codehaus.mojo_animal-sniffer-annotations-1.22.jar
# 2023-05-05 15:29:11,553 INFO sasl.SaslDataTransferClient: SASL encryption trust check: localHostTrusted = false, remoteHostTrusted = false
# 2023-05-05 15:29:11,592 INFO yarn.Client: Uploading resource file:/home/ubuntu/.ivy2/jars/io.grpc_grpc-netty-shaded-1.51.0.jar -> hdfs://namenode:9000/user/ubuntu/.sparkStaging/application_1683296918015_0005/io.grpc_grpc-netty-shaded-1.51.0.jar
# 2023-05-05 15:29:11,679 INFO sasl.SaslDataTransferClient: SASL encryption trust check: localHostTrusted = false, remoteHostTrusted = false
# 2023-05-05 15:29:12,415 INFO yarn.Client: Uploading resource file:/home/ubuntu/.ivy2/jars/io.perfmark_perfmark-api-0.26.0.jar -> hdfs://namenode:9000/user/ubuntu/.sparkStaging/application_1683296918015_0005/io.perfmark_perfmark-api-0.26.0.jar
# 2023-05-05 15:29:12,462 INFO sasl.SaslDataTransferClient: SASL encryption trust check: localHostTrusted = false, remoteHostTrusted = false
# 2023-05-05 15:29:12,525 INFO yarn.Client: Uploading resource file:/home/ubuntu/.ivy2/jars/io.grpc_grpc-googleapis-1.51.0.jar -> hdfs://namenode:9000/user/ubuntu/.sparkStaging/application_1683296918015_0005/io.grpc_grpc-googleapis-1.51.0.jar
# 2023-05-05 15:29:12,588 INFO sasl.SaslDataTransferClient: SASL encryption trust check: localHostTrusted = false, remoteHostTrusted = false
# 2023-05-05 15:29:12,638 INFO yarn.Client: Uploading resource file:/home/ubuntu/.ivy2/jars/io.grpc_grpc-xds-1.51.0.jar -> hdfs://namenode:9000/user/ubuntu/.sparkStaging/application_1683296918015_0005/io.grpc_grpc-xds-1.51.0.jar
# 2023-05-05 15:29:12,746 INFO sasl.SaslDataTransferClient: SASL encryption trust check: localHostTrusted = false, remoteHostTrusted = false
# 2023-05-05 15:29:13,773 INFO yarn.Client: Uploading resource file:/home/ubuntu/.ivy2/jars/io.opencensus_opencensus-proto-0.2.0.jar -> hdfs://namenode:9000/user/ubuntu/.sparkStaging/application_1683296918015_0005/io.opencensus_opencensus-proto-0.2.0.jar
# 2023-05-05 15:29:13,853 INFO sasl.SaslDataTransferClient: SASL encryption trust check: localHostTrusted = false, remoteHostTrusted = false
# 2023-05-05 15:29:13,912 INFO yarn.Client: Uploading resource file:/home/ubuntu/.ivy2/jars/io.grpc_grpc-services-1.51.0.jar -> hdfs://namenode:9000/user/ubuntu/.sparkStaging/application_1683296918015_0005/io.grpc_grpc-services-1.51.0.jar
# 2023-05-05 15:29:13,987 INFO sasl.SaslDataTransferClient: SASL encryption trust check: localHostTrusted = false, remoteHostTrusted = false
# 2023-05-05 15:29:14,098 INFO yarn.Client: Uploading resource file:/home/ubuntu/.ivy2/jars/com.google.re2j_re2j-1.6.jar -> hdfs://namenode:9000/user/ubuntu/.sparkStaging/application_1683296918015_0005/com.google.re2j_re2j-1.6.jar
# 2023-05-05 15:29:14,154 INFO sasl.SaslDataTransferClient: SASL encryption trust check: localHostTrusted = false, remoteHostTrusted = false
# 2023-05-05 15:29:14,214 INFO yarn.Client: Uploading resource file:/home/ubuntu/.ivy2/jars/dk.brics.automaton_automaton-1.11-8.jar -> hdfs://namenode:9000/user/ubuntu/.sparkStaging/application_1683296918015_0005/dk.brics.automaton_automaton-1.11-8.jar
# 2023-05-05 15:29:14,262 INFO sasl.SaslDataTransferClient: SASL encryption trust check: localHostTrusted = false, remoteHostTrusted = false
# 2023-05-05 15:29:14,335 INFO yarn.Client: Uploading resource file:/home/ubuntu/spark/python/lib/pyspark.zip -> hdfs://namenode:9000/user/ubuntu/.sparkStaging/application_1683296918015_0005/pyspark.zip
# 2023-05-05 15:29:14,471 INFO sasl.SaslDataTransferClient: SASL encryption trust check: localHostTrusted = false, remoteHostTrusted = false
# 2023-05-05 15:29:14,614 INFO yarn.Client: Uploading resource file:/home/ubuntu/spark/python/lib/py4j-0.10.9.5-src.zip -> hdfs://namenode:9000/user/ubuntu/.sparkStaging/application_1683296918015_0005/py4j-0.10.9.5-src.zip
# 2023-05-05 15:29:14,671 INFO sasl.SaslDataTransferClient: SASL encryption trust check: localHostTrusted = false, remoteHostTrusted = false
# 2023-05-05 15:29:14,734 WARN yarn.Client: Same path resource file:///home/ubuntu/.ivy2/jars/io.delta_delta-core_2.12-2.3.0.jar added multiple times to distributed cache.
# 2023-05-05 15:29:14,734 WARN yarn.Client: Same path resource file:///home/ubuntu/.ivy2/jars/com.johnsnowlabs.nlp_spark-nlp_2.12-4.4.0.jar added multiple times to distributed cache.
# 2023-05-05 15:29:14,734 WARN yarn.Client: Same path resource file:///home/ubuntu/.ivy2/jars/io.delta_delta-storage-2.3.0.jar added multiple times to distributed cache.
# 2023-05-05 15:29:14,734 WARN yarn.Client: Same path resource file:///home/ubuntu/.ivy2/jars/org.antlr_antlr4-runtime-4.8.jar added multiple times to distributed cache.
# 2023-05-05 15:29:14,734 WARN yarn.Client: Same path resource file:///home/ubuntu/.ivy2/jars/com.typesafe_config-1.4.2.jar added multiple times to distributed cache.
# 2023-05-05 15:29:14,734 WARN yarn.Client: Same path resource file:///home/ubuntu/.ivy2/jars/org.rocksdb_rocksdbjni-6.29.5.jar added multiple times to distributed cache.
# 2023-05-05 15:29:14,734 WARN yarn.Client: Same path resource file:///home/ubuntu/.ivy2/jars/com.amazonaws_aws-java-sdk-bundle-1.11.828.jar added multiple times to distributed cache.
# 2023-05-05 15:29:14,734 WARN yarn.Client: Same path resource file:///home/ubuntu/.ivy2/jars/com.github.universal-automata_liblevenshtein-3.0.0.jar added multiple times to distributed cache.
# 2023-05-05 15:29:14,735 WARN yarn.Client: Same path resource file:///home/ubuntu/.ivy2/jars/com.google.cloud_google-cloud-storage-2.16.0.jar added multiple times to distributed cache.
# 2023-05-05 15:29:14,735 WARN yarn.Client: Same path resource file:///home/ubuntu/.ivy2/jars/com.navigamez_greex-1.0.jar added multiple times to distributed cache.
# 2023-05-05 15:29:14,735 WARN yarn.Client: Same path resource file:///home/ubuntu/.ivy2/jars/com.johnsnowlabs.nlp_tensorflow-cpu_2.12-0.4.4.jar added multiple times to distributed cache.
# 2023-05-05 15:29:14,735 WARN yarn.Client: Same path resource file:///home/ubuntu/.ivy2/jars/it.unimi.dsi_fastutil-7.0.12.jar added multiple times to distributed cache.
# 2023-05-05 15:29:14,735 WARN yarn.Client: Same path resource file:///home/ubuntu/.ivy2/jars/org.projectlombok_lombok-1.16.8.jar added multiple times to distributed cache.
# 2023-05-05 15:29:14,735 WARN yarn.Client: Same path resource file:///home/ubuntu/.ivy2/jars/com.google.guava_guava-31.1-jre.jar added multiple times to distributed cache.
# 2023-05-05 15:29:14,735 WARN yarn.Client: Same path resource file:///home/ubuntu/.ivy2/jars/com.google.guava_failureaccess-1.0.1.jar added multiple times to distributed cache.
# 2023-05-05 15:29:14,735 WARN yarn.Client: Same path resource file:///home/ubuntu/.ivy2/jars/com.google.guava_listenablefuture-9999.0-empty-to-avoid-conflict-with-guava.jar added multiple times to distributed cache.
# 2023-05-05 15:29:14,735 WARN yarn.Client: Same path resource file:///home/ubuntu/.ivy2/jars/com.google.errorprone_error_prone_annotations-2.16.jar added multiple times to distributed cache.
# 2023-05-05 15:29:14,735 WARN yarn.Client: Same path resource file:///home/ubuntu/.ivy2/jars/com.google.j2objc_j2objc-annotations-1.3.jar added multiple times to distributed cache.
# 2023-05-05 15:29:14,735 WARN yarn.Client: Same path resource file:///home/ubuntu/.ivy2/jars/com.google.http-client_google-http-client-1.42.3.jar added multiple times to distributed cache.
# 2023-05-05 15:29:14,735 WARN yarn.Client: Same path resource file:///home/ubuntu/.ivy2/jars/io.opencensus_opencensus-contrib-http-util-0.31.1.jar added multiple times to distributed cache.
# 2023-05-05 15:29:14,735 WARN yarn.Client: Same path resource file:///home/ubuntu/.ivy2/jars/com.google.http-client_google-http-client-jackson2-1.42.3.jar added multiple times to distributed cache.
# 2023-05-05 15:29:14,735 WARN yarn.Client: Same path resource file:///home/ubuntu/.ivy2/jars/com.google.http-client_google-http-client-gson-1.42.3.jar added multiple times to distributed cache.
# 2023-05-05 15:29:14,736 WARN yarn.Client: Same path resource file:///home/ubuntu/.ivy2/jars/com.google.api-client_google-api-client-2.1.1.jar added multiple times to distributed cache.
# 2023-05-05 15:29:14,736 WARN yarn.Client: Same path resource file:///home/ubuntu/.ivy2/jars/commons-codec_commons-codec-1.15.jar added multiple times to distributed cache.
# 2023-05-05 15:29:14,736 WARN yarn.Client: Same path resource file:///home/ubuntu/.ivy2/jars/com.google.oauth-client_google-oauth-client-1.34.1.jar added multiple times to distributed cache.
# 2023-05-05 15:29:14,737 WARN yarn.Client: Same path resource file:///home/ubuntu/.ivy2/jars/com.google.http-client_google-http-client-apache-v2-1.42.3.jar added multiple times to distributed cache.
# 2023-05-05 15:29:14,737 WARN yarn.Client: Same path resource file:///home/ubuntu/.ivy2/jars/com.google.apis_google-api-services-storage-v1-rev20220705-2.0.0.jar added multiple times to distributed cache.
# 2023-05-05 15:29:14,737 WARN yarn.Client: Same path resource file:///home/ubuntu/.ivy2/jars/com.google.code.gson_gson-2.10.jar added multiple times to distributed cache.
# 2023-05-05 15:29:14,737 WARN yarn.Client: Same path resource file:///home/ubuntu/.ivy2/jars/com.google.cloud_google-cloud-core-2.9.0.jar added multiple times to distributed cache.
# 2023-05-05 15:29:14,737 WARN yarn.Client: Same path resource file:///home/ubuntu/.ivy2/jars/com.google.auto.value_auto-value-annotations-1.10.1.jar added multiple times to distributed cache.
# 2023-05-05 15:29:14,737 WARN yarn.Client: Same path resource file:///home/ubuntu/.ivy2/jars/com.google.cloud_google-cloud-core-http-2.9.0.jar added multiple times to distributed cache.
# 2023-05-05 15:29:14,737 WARN yarn.Client: Same path resource file:///home/ubuntu/.ivy2/jars/com.google.http-client_google-http-client-appengine-1.42.3.jar added multiple times to distributed cache.
# 2023-05-05 15:29:14,737 WARN yarn.Client: Same path resource file:///home/ubuntu/.ivy2/jars/com.google.api_gax-httpjson-0.105.1.jar added multiple times to distributed cache.
# 2023-05-05 15:29:14,737 WARN yarn.Client: Same path resource file:///home/ubuntu/.ivy2/jars/com.google.cloud_google-cloud-core-grpc-2.9.0.jar added multiple times to distributed cache.
# 2023-05-05 15:29:14,738 WARN yarn.Client: Same path resource file:///home/ubuntu/.ivy2/jars/io.grpc_grpc-core-1.51.0.jar added multiple times to distributed cache.
# 2023-05-05 15:29:14,738 WARN yarn.Client: Same path resource file:///home/ubuntu/.ivy2/jars/com.google.api_gax-2.20.1.jar added multiple times to distributed cache.
# 2023-05-05 15:29:14,738 WARN yarn.Client: Same path resource file:///home/ubuntu/.ivy2/jars/com.google.api_gax-grpc-2.20.1.jar added multiple times to distributed cache.
# 2023-05-05 15:29:14,738 WARN yarn.Client: Same path resource file:///home/ubuntu/.ivy2/jars/io.grpc_grpc-alts-1.51.0.jar added multiple times to distributed cache.
# 2023-05-05 15:29:14,738 WARN yarn.Client: Same path resource file:///home/ubuntu/.ivy2/jars/io.grpc_grpc-grpclb-1.51.0.jar added multiple times to distributed cache.
# 2023-05-05 15:29:14,738 WARN yarn.Client: Same path resource file:///home/ubuntu/.ivy2/jars/org.conscrypt_conscrypt-openjdk-uber-2.5.2.jar added multiple times to distributed cache.
# 2023-05-05 15:29:14,738 WARN yarn.Client: Same path resource file:///home/ubuntu/.ivy2/jars/io.grpc_grpc-protobuf-1.51.0.jar added multiple times to distributed cache.
# 2023-05-05 15:29:14,739 WARN yarn.Client: Same path resource file:///home/ubuntu/.ivy2/jars/com.google.auth_google-auth-library-credentials-1.13.0.jar added multiple times to distributed cache.
# 2023-05-05 15:29:14,739 WARN yarn.Client: Same path resource file:///home/ubuntu/.ivy2/jars/com.google.auth_google-auth-library-oauth2-http-1.13.0.jar added multiple times to distributed cache.
# 2023-05-05 15:29:14,739 WARN yarn.Client: Same path resource file:///home/ubuntu/.ivy2/jars/com.google.api_api-common-2.2.2.jar added multiple times to distributed cache.
# 2023-05-05 15:29:14,739 WARN yarn.Client: Same path resource file:///home/ubuntu/.ivy2/jars/javax.annotation_javax.annotation-api-1.3.2.jar added multiple times to distributed cache.
# 2023-05-05 15:29:14,739 WARN yarn.Client: Same path resource file:///home/ubuntu/.ivy2/jars/io.opencensus_opencensus-api-0.31.1.jar added multiple times to distributed cache.
# 2023-05-05 15:29:14,739 WARN yarn.Client: Same path resource file:///home/ubuntu/.ivy2/jars/io.grpc_grpc-context-1.51.0.jar added multiple times to distributed cache.
# 2023-05-05 15:29:14,739 WARN yarn.Client: Same path resource file:///home/ubuntu/.ivy2/jars/com.google.api.grpc_proto-google-iam-v1-1.6.22.jar added multiple times to distributed cache.
# 2023-05-05 15:29:14,740 WARN yarn.Client: Same path resource file:///home/ubuntu/.ivy2/jars/com.google.protobuf_protobuf-java-3.21.10.jar added multiple times to distributed cache.
# 2023-05-05 15:29:14,740 WARN yarn.Client: Same path resource file:///home/ubuntu/.ivy2/jars/com.google.protobuf_protobuf-java-util-3.21.10.jar added multiple times to distributed cache.
# 2023-05-05 15:29:14,740 WARN yarn.Client: Same path resource file:///home/ubuntu/.ivy2/jars/com.google.api.grpc_proto-google-common-protos-2.11.0.jar added multiple times to distributed cache.
# 2023-05-05 15:29:14,740 WARN yarn.Client: Same path resource file:///home/ubuntu/.ivy2/jars/org.threeten_threetenbp-1.6.4.jar added multiple times to distributed cache.
# 2023-05-05 15:29:14,741 WARN yarn.Client: Same path resource file:///home/ubuntu/.ivy2/jars/com.google.api.grpc_proto-google-cloud-storage-v2-2.16.0-alpha.jar added multiple times to distributed cache.
# 2023-05-05 15:29:14,741 WARN yarn.Client: Same path resource file:///home/ubuntu/.ivy2/jars/com.google.api.grpc_grpc-google-cloud-storage-v2-2.16.0-alpha.jar added multiple times to distributed cache.
# 2023-05-05 15:29:14,741 WARN yarn.Client: Same path resource file:///home/ubuntu/.ivy2/jars/com.google.api.grpc_gapic-google-cloud-storage-v2-2.16.0-alpha.jar added multiple times to distributed cache.
# 2023-05-05 15:29:14,741 WARN yarn.Client: Same path resource file:///home/ubuntu/.ivy2/jars/com.fasterxml.jackson.core_jackson-core-2.14.1.jar added multiple times to distributed cache.
# 2023-05-05 15:29:14,742 WARN yarn.Client: Same path resource file:///home/ubuntu/.ivy2/jars/com.google.code.findbugs_jsr305-3.0.2.jar added multiple times to distributed cache.
# 2023-05-05 15:29:14,742 WARN yarn.Client: Same path resource file:///home/ubuntu/.ivy2/jars/io.grpc_grpc-api-1.51.0.jar added multiple times to distributed cache.
# 2023-05-05 15:29:14,742 WARN yarn.Client: Same path resource file:///home/ubuntu/.ivy2/jars/io.grpc_grpc-auth-1.51.0.jar added multiple times to distributed cache.
# 2023-05-05 15:29:14,742 WARN yarn.Client: Same path resource file:///home/ubuntu/.ivy2/jars/io.grpc_grpc-stub-1.51.0.jar added multiple times to distributed cache.
# 2023-05-05 15:29:14,742 WARN yarn.Client: Same path resource file:///home/ubuntu/.ivy2/jars/org.checkerframework_checker-qual-3.28.0.jar added multiple times to distributed cache.
# 2023-05-05 15:29:14,742 WARN yarn.Client: Same path resource file:///home/ubuntu/.ivy2/jars/com.google.api.grpc_grpc-google-iam-v1-1.6.22.jar added multiple times to distributed cache.
# 2023-05-05 15:29:14,742 WARN yarn.Client: Same path resource file:///home/ubuntu/.ivy2/jars/io.grpc_grpc-protobuf-lite-1.51.0.jar added multiple times to distributed cache.
# 2023-05-05 15:29:14,742 WARN yarn.Client: Same path resource file:///home/ubuntu/.ivy2/jars/com.google.android_annotations-4.1.1.4.jar added multiple times to distributed cache.
# 2023-05-05 15:29:14,742 WARN yarn.Client: Same path resource file:///home/ubuntu/.ivy2/jars/org.codehaus.mojo_animal-sniffer-annotations-1.22.jar added multiple times to distributed cache.
# 2023-05-05 15:29:14,742 WARN yarn.Client: Same path resource file:///home/ubuntu/.ivy2/jars/io.grpc_grpc-netty-shaded-1.51.0.jar added multiple times to distributed cache.
# 2023-05-05 15:29:14,742 WARN yarn.Client: Same path resource file:///home/ubuntu/.ivy2/jars/io.perfmark_perfmark-api-0.26.0.jar added multiple times to distributed cache.
# 2023-05-05 15:29:14,742 WARN yarn.Client: Same path resource file:///home/ubuntu/.ivy2/jars/io.grpc_grpc-googleapis-1.51.0.jar added multiple times to distributed cache.
# 2023-05-05 15:29:14,742 WARN yarn.Client: Same path resource file:///home/ubuntu/.ivy2/jars/io.grpc_grpc-xds-1.51.0.jar added multiple times to distributed cache.
# 2023-05-05 15:29:14,742 WARN yarn.Client: Same path resource file:///home/ubuntu/.ivy2/jars/io.opencensus_opencensus-proto-0.2.0.jar added multiple times to distributed cache.
# 2023-05-05 15:29:14,742 WARN yarn.Client: Same path resource file:///home/ubuntu/.ivy2/jars/io.grpc_grpc-services-1.51.0.jar added multiple times to distributed cache.
# 2023-05-05 15:29:14,743 WARN yarn.Client: Same path resource file:///home/ubuntu/.ivy2/jars/com.google.re2j_re2j-1.6.jar added multiple times to distributed cache.
# 2023-05-05 15:29:14,743 WARN yarn.Client: Same path resource file:///home/ubuntu/.ivy2/jars/dk.brics.automaton_automaton-1.11-8.jar added multiple times to distributed cache.
# 2023-05-05 15:29:16,145 INFO yarn.Client: Uploading resource file:/tmp/spark-b9e75af4-33b9-45eb-99f1-99e73e11f69f/__spark_conf__8752628331429744667.zip -> hdfs://namenode:9000/user/ubuntu/.sparkStaging/application_1683296918015_0005/__spark_conf__.zip
# 2023-05-05 15:29:16,187 INFO sasl.SaslDataTransferClient: SASL encryption trust check: localHostTrusted = false, remoteHostTrusted = false
# 2023-05-05 15:29:16,294 INFO spark.SecurityManager: Changing view acls to: ubuntu
# 2023-05-05 15:29:16,294 INFO spark.SecurityManager: Changing modify acls to: ubuntu
# 2023-05-05 15:29:16,295 INFO spark.SecurityManager: Changing view acls groups to:
# 2023-05-05 15:29:16,295 INFO spark.SecurityManager: Changing modify acls groups to:
# 2023-05-05 15:29:16,295 INFO spark.SecurityManager: SecurityManager: authentication disabled; ui acls disabled; users  with view permissions: Set(ubuntu); groups with view permissions: Set(); users  with modify permissions: Set(ubuntu); groups with modify permissions: Set()
# 2023-05-05 15:29:16,345 INFO yarn.Client: Submitting application application_1683296918015_0005 to ResourceManager
# 2023-05-05 15:29:16,617 INFO impl.YarnClientImpl: Submitted application application_1683296918015_0005
# 2023-05-05 15:29:17,625 INFO yarn.Client: Application report for application_1683296918015_0005 (state: ACCEPTED)
# 2023-05-05 15:29:17,634 INFO yarn.Client:
# 	 client token: N/A
# 	 diagnostics: AM container is launched, waiting for AM container to Register with RM
# 	 ApplicationMaster host: N/A
# 	 ApplicationMaster RPC port: -1
# 	 queue: default
# 	 start time: 1683300556503
# 	 final status: UNDEFINED
# 	 tracking URL: http://namenode:8088/proxy/application_1683296918015_0005/
# 	 user: ubuntu
# 2023-05-05 15:29:18,637 INFO yarn.Client: Application report for application_1683296918015_0005 (state: ACCEPTED)
# 2023-05-05 15:29:19,639 INFO yarn.Client: Application report for application_1683296918015_0005 (state: ACCEPTED)
# 2023-05-05 15:29:20,641 INFO yarn.Client: Application report for application_1683296918015_0005 (state: ACCEPTED)
# 2023-05-05 15:29:21,643 INFO yarn.Client: Application report for application_1683296918015_0005 (state: ACCEPTED)
# 2023-05-05 15:29:22,646 INFO yarn.Client: Application report for application_1683296918015_0005 (state: ACCEPTED)
# 2023-05-05 15:29:23,649 INFO yarn.Client: Application report for application_1683296918015_0005 (state: ACCEPTED)
# 2023-05-05 15:29:24,659 INFO yarn.Client: Application report for application_1683296918015_0005 (state: ACCEPTED)

# %%
spark.catalog.clearCache()
spark.conf.set("spark.sql.broadcastTimeout", 100000)

# %%
books_data = "hdfs:/project/books_data2/part*"
books_ratings = "hdfs:/project/books_ratings2/part*"

# %%
schema_books = "Title STRING, Description STRING, Authors STRING, Image STRING, PreviewLink STRING, Publisher STRING, PublishedDate DATE, InfoLink STRING, Categories STRING, RatingsCount INT"
schema_ratings = "ID STRING, Title STRING, Price INT, User_id STRING, User_name STRING, Helpfulness STRING, Score FLOAT, Timestamp INT, Summary STRING, Review STRING"

# %%
df_books = spark.read \
    .format("csv") \
    .schema(schema_books) \
    .option("header", "false") \
    .option("delimiter", "|") \
    .load(books_data)
df_ratings = spark.read \
    .format("csv") \
    .schema(schema_ratings) \
    .option("header", "false") \
    .option("delimiter", "|") \
    .load(books_ratings)

# %%
# errasing not needed columns
df_books = df_books.drop("PublishedDate","Description","Authors", "Image", "PreviewLink", "Publisher", "PublishedDate","InfoLink","RatingsCount")
df_ratings = df_ratings.drop("ID", "Price","User_id","User_name","helpfulness", "Timestamp","Summary")

# %%
df_books = df_books.repartition(150)
df_ratings = df_ratings.repartition(150)

# %%
# cleaning null values
df_books = df_books.na.drop(subset=["Categories", "Title"])
df_ratings = df_ratings.na.drop(subset=["Title", "Score", "Review"])
first_row = df_ratings.limit(1)
df_ratings = df_ratings.subtract(first_row)

# %% [markdown]
# SENTIMENT ANALYSIS

# %%
document = DocumentAssembler() \
    .setInputCol("Review") \
    .setOutputCol("document")

token = Tokenizer() \
    .setInputCols(["document"]) \
    .setOutputCol("token")

normalizer = Normalizer() \
    .setInputCols(["token"]) \
    .setOutputCol("normal")

vivekn = ViveknSentimentModel.pretrained() \
    .setInputCols(["document", "normal"]) \
    .setOutputCol("result_sentiment")

finisher = Finisher() \
    .setInputCols(["result_sentiment"]) \
    .setOutputCols(["Sentiment"]) \
    .setCleanAnnotations(True)

pipeline = Pipeline().setStages([document, token, normalizer, vivekn, finisher])

pipelineModel = pipeline.fit(df_ratings)
df_ratings = pipelineModel.transform(df_ratings)
# Out:
# sentiment_vivekn download started this may take some time.
# 2023-05-05 15:00:16,124 INFO Credentials: Connecting to AWS with Anonymous AWS Credentials...
# Approximate size to download 873.6 KB
# [ | ]sentiment_vivekn download started this may take some time.
# Approximate size to download 873.6 KB
# Download done! Loading the resource.
# [ / ]
# [Stage 0:>                                                          (0 + 1) / 1]
# [ — ]
# [ \ ]
# [Stage 1:=========================================>               (58 + 0) / 80]
# [ | ]
# [ / ]
# [Stage 2:=================================>                       (47 + 0) / 80]
# [ \ ]
# [Stage 3:==================================>                      (48 + 4) / 80]
# [ | ]
# [OK!]

# %%
df_books.write \
    .mode("overwrite").format("delta").save("/tmp/books")
df_ratings \
    .write.mode("overwrite").format("delta").save("/tmp/ratings1")

# %%
# replacing positive/negative with value
df_ratings = df_ratings.withColumn('Sentiment', F.when(df_ratings.Sentiment[0] == "positive", 1).otherwise(0)).cache()

# %%
df_ratings = df_ratings.repartition("Title")

# %% [markdown]
# Count between 50 and 100

# %%
# First, calculate the count for each title
df_count = df_ratings.groupBy("Title").agg(F.count("*").alias("Count"))
df_ratings.unpersist()

# Filter the DataFrame based on the count
df_count_filtered = df_count.filter(df_count["Count"] > 50).cache()

# %%
#using brodacast as optimization
df_ratings_filtered = df_ratings.join(F.broadcast(df_count_filtered), "Title")

# Now, calculate the average scores and sentiments

df_ratings = df_ratings_filtered.groupBy("Title", "Count").agg(
    F.mean("Score").alias("Scores"),
    F.mean("Sentiment").alias("Sentiments")
)

df_count_filtered.unpersist()
# Out:
# DataFrame[Title: string, Count: bigint]

# %%
df_ratings \
    .write.mode("overwrite").format("delta").save("/tmp/ratings_count")

# %%
# upper limit for amount of reviews
df_ratings_updated = df_ratings.withColumn('Count', F.when(F.col("Count") > 100, 100).otherwise(F.col("Count")))

# %%
df_ratings_updated \
    .write.mode("overwrite").format("delta").save("/tmp/ratings_count_updated")

# %% [markdown]
# Merging of delta tables

# %%
# Read data from the Delta tables
df_ratings_temp = spark.read.format("delta").load("/tmp/ratings_count")
df_ratings_updated_temp = spark.read.format("delta").load("/tmp/ratings_count_updated")

# Read the data back as Delta tables
delta_table_ratings = DeltaTable.forPath(spark, "/tmp/ratings_count")

# Perform the MERGE INTO operation
delta_table_ratings.alias("ratings1") \
    .merge(df_ratings_updated_temp.alias("ratings1_updated"),
           "ratings1.Title = ratings1_updated.Title AND ratings1.Scores = ratings1_updated.Scores") \
    .whenMatchedUpdate(set={"Count": "ratings1_updated.Count"}) \
    .whenNotMatchedInsertAll() \
    .execute()

# Save the merged data back to the original Delta table
delta_table_ratings.toDF().write.format("delta").mode("overwrite").save("/tmp/ratings_count")

# %%
df_ratings = spark.read.format("delta").load("/tmp/ratings_count")

# %%
# calculating weighted values to get the final score of each book

final_ratings = df_ratings.withColumn(
    "Final_score", 0.04 * F.col("Count") + 0.3 *2* F.col("Scores") + 0.3 *10* F.col("Sentiments")
)
final_ratings = final_ratings.na.drop(subset=["Final_score"])

# %%
final_ratings = final_ratings.select("Title", "Final_score").cache()
#final_ratings.cache()

# %%
df_books = df_books.withColumn("Categories", F.translate("Categories", "[]'", ""))
df_books = df_books.withColumn("Categories", F.split(F.col("Categories"), ", "))

second_df = df_books.select("Title", F.col("Categories").getItem(0).alias("Category"))

# joining tables
final_ratings = final_ratings.join(F.broadcast(second_df), on="Title")
# deleting duplicates
final_ratings = final_ratings.dropDuplicates(['Title'])

# %%
merged_df = final_ratings.withColumn(
    "Title_final_score", 
    F.concat(F.col("Title"), F.lit(" - "), F.format_number(F.col("Final_score"), 2))
)
merged_df.cache()
final_ratings.unpersist()
# Out:
# DataFrame[Title: string, Final_score: double, Category: string]

# %%
from pyspark.sql.window import Window

# making ranking
window = Window.partitionBy('Category').orderBy(F.desc('Final_score'))

# using extra counter column
df = merged_df.withColumn('counter', F.row_number().over(window))
merged_df.unpersist()
# Out:
# DataFrame[Title: string, Final_score: double, Category: string, Title_final_score: string]

# %%
# pivoting
pivot_df = df.groupBy('counter').pivot('Category').agg(F.first('Title_final_score'))
pivot_df = pivot_df.drop('counter')

# %%
pivot_df.show(truncate=False)
# Out:
# +-------------------------------+-----------------------------------------------+------------------------------------------------------------------------------+--------------------------------------------------------------------------------------------------------------------------+-------------------------------------------------------------------+-------------------------------------------------------------------------------+------------------+-------------------+-----------------------------------------------------------+----------------------------+---------------------------+---------------------------+-------------+---------------------------------------------------------------+----------------------------------------------+-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+----------------------------------------------------------------+----------------------------------------------------------------------------------------------------------------------+------------------------------------------------------------------+----------------------------------------+--------------------------------------------+---------------------------------------------------+---------------------------------------------------------+--------------------------------------+--------------------------------+------------------------------+-----------+------------------------------+-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+-----------------------------------------------------------------------------+----------------------------------------------------------+------------------------------------------------------------------+----------------------+--------------------------------+---------------------+-----------------------------------------------------------------+---------------------+------------------------------------------------------------------+---------------------------------------------------------------------------------+--------------------------------------------------------------+---------------------------------------------------------------+----------------------------------------------------------------------------------------------+------------------------------------------------------------------------------------------------------------------+---------------------------------------------------------+-----------------------------------------------------------------------------+------------------------+--------------------------------------------------------------------------------+---------------------------------+----------------------------------------------------------------------------------------------+-----------------------------+-----------------------------------------------+------------------------------------+--------------------------------+---------------------------------------------------------------------------+---------------------------------------------------------------------------------------------------------------------+--------------------------------+------------------------------------+----------------------------------------------------------------+------------------------------------------------------------------------------------+--------------------------------------------+-------------------------+--------------------------------+-------------------------------------------+---------------------------------+----------------------------------------------------------------------------+-------------------------------------------------------------------------------------+-------------------------------------------------------+---------------------------------------------------------------------------------+--- ...
# | FEVERBORN                     |"""Childrens literature"""                     |"""Childrens plays                                                            |"""Childrens stories                                                                                                      |"""Childrens stories"""                                            |2021-07-20                                                                     |Abandoned children|Abortion           |Absurd (Philosophy)                                        |Accountants                 |Actresses                  |Administration of estates  |Admirals     |Adopted children                                               |Adoptees                                      |Adultery                                                                                                                                                                                               |Adventure stories                                               |Aeronautics                                                                                                           |Africa                                                            |African American civil rights workers   |African American criminals                  |African Americans                                  |Ahab                                                     |Alcoholics                            |Algeria                         |Alienation (Social psychology)|Alligators |American Dream                |American fiction                                                                                                                                                                               |American literature                                                          |American periodicals                                      |American wit and humor                                            |Americanisms          |Americans                       |Amnesia              |Amusements                                                       |Animal behavior      |Animal communication                                              |Animals                                                                          |Anti-Jewish propaganda                                        |Antiquities                                                    |Apologetics                                                                                   |Application software                                                                                              |Apprentices                                              |Archers                                                                      |Architects              |Architecture                                                                    |Arka Tech                        |Art                                                                                           |Arthurian romances           |Asia                                           |Assassination                       |Atonement                       |Audio equipment industry                                                   |Audiobooks                                                                                                           |Australia                       |Australian fiction                  |Austria                                                         |Authors                                                                             |Automobile travel / United States           |BIOGRAPHY & AUTOBIOGRAPHY|Badgers                         |Baggins                                    |Baking                           |Banks and banking                                                           |Baseball                                                                             |Beauty                                                 |Beauty contests                                                                  |Beh ...
# +-------------------------------+-----------------------------------------------+------------------------------------------------------------------------------+--------------------------------------------------------------------------------------------------------------------------+-------------------------------------------------------------------+-------------------------------------------------------
null                                                                        |null                                                                                 |null                                                   |null                                                                             |nul ...
# |null                           |null                                           |null                                                                          |null                                                                                                                      |Ramona the Pest - 8.54                                             |null                                                                           |null              |null               |null                                                       |null                        |null                       |null                       |null         |null                                                           |null                                          |null                                                                                                                                                                                                   |null                                                            |null                                                                                                                  |null                                                              |null                                    |null                                        |Up From Slavery - 8.02                             |null                                                     |null                                  |null                            |null                          |null       |null                          |Sweet Hereafter: A Novel - 7.93                                                                                                                                                                |Riders of the Purple Sage (Unabridged Classics in MP3) - 6.19                |null                                                      |null                                                              |null                  |null                            |null                 |null                                                             |null                 |null                                                              |Jungle Book (Classic Library) - 8.65                                             |null                                                          |null                                                           |null                                                                                          |null                                                                                                              |null                                                     |null                                                                         |null                    |null                                                                            |null                             |The Lost Painting: The Quest for a Caravaggio Masterpiece - 8.12                              |null                         |null                                           |null                                |null                            |null                                                                       |The Picture of Dorian Gray (Classic Collection (Brilliance Audio)) - 8.20                                            |null                            |null                                |null                                                            |null                                                                                |null                                        |null                     |null                            |null                                       |null                             |null                                                                        |null                                                                                 |null                                                   |null                                                                             |nul ...
# |null                           |null                                           |null                                                                          |null                                                                                                                      |Bridge to Terabithia - 8.53                                        |null                                                                           |null              |null               |null                                                       |null                        |null                       |null                       |null         |null                                                           |null                                          |null                                                                                                                                                                                                   |null                                                            |null                                                                                                                  |null                                                              |null                                    |null                                        |Up from Slavery - 8.01                             |null                                                     |null                                  |null                            |null                          |null       |null                          |Batman: Haunted knight : the legends of the Dark Knight Halloween specials : three tales of Halloween in Gotham City / Jeph Loeb & Tim Sale, ... Wright, colorist ; Todd Klein, letterer - 6.63|null                                                                         |null                                                      |null                                                              |null                  |null                            |null                 |null                                                             |null                 |null                                                              |Big Box of Boynton: Barnyard Dance! Pajama Time! Oh My Oh My Oh Dinosaurs! - 8.15|null                                                          |null                                                           |null                                                                                          |null                                                                                                              |null                                                     |null                                                                         |null                    |null                                                                            |null                             |Collage Discovery Workshop - 7.67                                                             |null                         |null                                           |null                                |null                            |null                                                                       |The Tesseract (Nova Audio Books) - 7.96                                                                              |null                            |null                                |null                                                            |null                                                                                |null                                        |null                     |null                            |null                                       |null                             |null                                                                        |null                                                                                 |null                                                   |null                                                                             |nul ...
# |null                           |null                                           |null                                                                          |null                                                                                                                      |The Music of Dolphins - 8.33                                       |null                                                                           |null              |null               |null                                                       |null                        |null                       |null                       |null         |null                                                           |null                                          |null                                                                                                                                                                                                   |null                                                            |null                                                                                                                  |null                                                              |null                                    |null                                        |null                                               |null                                                     |null                                  |null                            |null                          |null       |null                          |null                                                                                                                                                                                           |null                                                                         |null                                                      |null                                                              |null                  |null                            |null                 |null                                                             |null                 |null                                                              |The Jungle - 8.10                                                                |null                                                          |null                                                           |null                                                                                          |null                                                                                                              |null                                                     |null                                                                         |null                    |null                                                                            |null                             |The Judgment of Paris: Manet, Meissonier and the Birth of Impressionism - 7.18                |null                         |null                                           |null                                |null                            |null                                                                       |Charms for the Easy Life (Chivers Sound Library) - 7.54                                                              |null                            |null                                |null                                                            |null                                                                                |null                                        |null                     |null                            |null                                       |null                             |null                                                                        |null                                                                                 |null                                                   |null                                                                             |nul ...
# |null                           |null                                           |null                                                                          |null                                                                                                                      |The Wonderful Wizard of Oz (Lrs Large Print Heritage Series) - 8.12|null                                                                           |null              |null               |null                                                       |null                        |null                       |null                       |null         |null                                                           |null                                          |null                                                                                                                                                                                                   |null                                                            |null                                                                                                                  |null                                                              |null                                    |null                                        |null                                               |null                                                     |null                                  |null                            |null                          |null       |null                          |null                                                                                                                                                                                           |null                                                                         |null                                                      |null                                                              |null                  |null                            |null                 |null                                                             |null                 |null                                                              |The 101 Dalmatians - 6.98                                                        |null                                                          |null                                                           |null                                                                                          |null                                                                                                              |null                                                     |null                                                                         |null                    |null                                                                            |null                             |Figure drawing - 7.14                                                                         |null                         |null                                           |null                                |null                            |null                                                                       |The Pilgrim's Progress; Cassette - 7.17                                                                              |null                            |null                                |null                                                            |null                                                                                |null                                        |null                     |null                            |null                                       |null                             |null                                                                        |null                                                                                 |null                                                   |null                                                                             |nul ...
# |null                           |null                                           |null                                                                          |null                                                                                                                      |Mr. Peabody's Apples - 8.10                                        |null                                                                           |null              |null               |null                                                       |null                        |null                       |null                       |null         |null                                                           |null                                          |null                                                                                                                                                                                                   |null                                                            |null                                                                                                                  |null                                                              |null                                    |null                                        |null                                               |null                                                     |null                                  |null                            |null                          |null       |null                          |null                                                                                                                                                                                           |null                                                                         |null                                                      |null                                                              |null                  |null                            |null                 |null                                                             |null                 |null                                                              |null                                                                             |null                                                          |null                                                           |null                                                                                          |null                                                                                                              |null                                                     |null                                                                         |null                    |null                                                                            |null                             |Zen in the art of archery (A Vintage book, V-663) - 6.99                                      |null                         |null                                           |null                                |null                            |null                                                                       |Pilgrim's Progress (Hodder Christian Audio) - 7.17                                                                   |null                            |null                                |null                                                            |null                                                                                |null                                        |null                     |null                            |null                                       |null                             |null                                                                        |null                                                                                 |null                                                   |null                                                                             |nul ...
# ...
# |null                           |null                                           |null                                                                          |null                                                                                                                      |null                                                               |null                                                                           |null              |null               |null                                                       |null                        |null                       |null                       |null         |null                                                           |null                                          |null                                                                                                                                                                                                   |null                                                            |null                                                                                                                  |null                                                              |null                                    |null                                        |null                                               |null                                                     |null                                  |null                            |null                          |null       |null                          |null                                                                                                                                                                                           |null                                                                         |null                                                      |null                                                              |null                  |null                            |null                 |null                                                             |null                 |null                                                              |null                                                                             |null                                                          |null                                                           |null                                                                                          |null                                                                                                              |null                                                     |null                                                                         |null                    |null                                                                            |null                             |null                                                                                          |null                         |null                                           |null                                |null                            |null                                                                       |null                                                                                                                 |null                            |null                                |null                                                            |null                                                                                |null                                        |null                     |null                            |null                                       |null                             |null                                                                        |null                                                                                 |null                                                   |null                                                                             |nul ...
# |null                           |null                                           |null                                                                          |null                                                                                                                      |null                                                               |null                                                                           |null              |null               |null                                                       |null                        |null                       |null                       |null         |null                                                           |null                                          |null                                                                                                                                                                                                   |null                                                            |null                                                                                                                  |null                                                              |null                                    |null                                        |null                                               |null                                                     |null                                  |null                            |null                          |null       |null                          |null                                                                                                                                                                                           |null                                                                         |null                                                      |null                                                              |null                  |null                            |null                 |null                                                             |null                 |null                                                              |null                                                                             |null                                                          |null                                                           |null                                                                                          |null                                                                                                              |null                                                     |null                                                                         |null                    |null                                                                            |null                             |null                                                                                          |null                         |null                                           |null                                |null                            |null                                                                       |null                                                                                                                 |null                            |null                                |null                                                            |null                                                                                |null                                        |null                     |null                            |null                                       |null                             |null                                                                        |null                                                                                 |null                                                   |null                                                                             |nul ...
# +-------------------------------+-----------------------------------------------+------------------------------------------------------------------------------+--------------------------------------------------------------------------------------------------------------------------+-------------------------------------------------------------------+-------------------------------------------------------------------------------+------------------+-------------------+-----------------------------------------------------------+----------------------------+---------------------------+---------------------------+-------------+---------------------------------------------------------------+----------------------------------------------+-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+----------------------------------------------------------------+----------------------------------------------------------------------------------------------------------------------+------------------------------------------------------------------+----------------------------------------+--------------------------------------------+---------------------------------------------------+---------------------------------------------------------+--------------------------------------+--------------------------------+------------------------------+-----------+------------------------------+-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+-----------------------------------------------------------------------------+----------------------------------------------------------+------------------------------------------------------------------+----------------------+--------------------------------+---------------------+-----------------------------------------------------------------+---------------------+------------------------------------------------------------------+---------------------------------------------------------------------------------+--------------------------------------------------------------+---------------------------------------------------------------+----------------------------------------------------------------------------------------------+------------------------------------------------------------------------------------------------------------------+---------------------------------------------------------+-----------------------------------------------------------------------------+------------------------+--------------------------------------------------------------------------------+---------------------------------+----------------------------------------------------------------------------------------------+-----------------------------+-----------------------------------------------+------------------------------------+--------------------------------+---------------------------------------------------------------------------+---------------------------------------------------------------------------------------------------------------------+--------------------------------+------------------------------------+----------------------------------------------------------------+------------------------------------------------------------------------------------+--------------------------------------------+-------------------------+--------------------------------+-------------------------------------------+---------------------------------+----------------------------------------------------------------------------+-------------------------------------------------------------------------------------+-------------------------------------------------------+---------------------------------------------------------------------------------+--- ...
# only showing top 20 rows
